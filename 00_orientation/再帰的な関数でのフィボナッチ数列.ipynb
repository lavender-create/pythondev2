# %%
import prognum

n = int(input("何番目の数値を求めますか？："))

print(f"何番目の数値を求めますか？：{n}")
print(prognum.fibo(n))
# Out:
# 何番目の数値を求めますか？：8
# 21

# %%
n = int(input("何番目の数値を求めますか？："))

print(f"何番目の数値を求めますか？：{n}")
print(prognum.fibo(n))
# Out:
# 何番目の数値を求めますか？：9
# 34

# %%
n = int(input("何番目の数値を求めますか？："))

print(f"何番目の数値を求めますか？：{n}")
print(prognum.fibo(n))
# Out:
# 何番目の数値を求めますか？：10
# 55
