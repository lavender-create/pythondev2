# %%
alfa_code = {}
alfa_code = dict.fromkeys(list("abcdefghijklmnopqrstuvwxyz"), 0)
alfa_code
# Out:
# {'a': 0,
#  'b': 0,
#  'c': 0,
#  'd': 0,
#  'e': 0,
#  'f': 0,
#  'g': 0,
#  'h': 0,
#  'i': 0,
#  'j': 0,
#  'k': 0,
#  'l': 0,
#  'm': 0,
#  'n': 0,
#  'o': 0,
#  'p': 0,
#  'q': 0,
#  'r': 0,
#  's': 0,
#  't': 0,
#  'u': 0,
#  'v': 0,
#  'w': 0,
#  'x': 0,
#  'y': 0,
#  'z': 0}

# %%
word=[]
word= input("英単語を入力してください：")
print(f"英単語を入力してください：{word} ")
# Out:
# 英単語を入力してください：dog

# %%
alfa_code = {}
alfa_code = dict.fromkeys(list("abcdefghijklmnopqrstuvwxyz"), 0)

# 未入力になるまで英単語を繰り返し受け付け
while True:
    alfa_code= input("英単語を入力してください：")
    if  i == "":
        break  # 未入力でEnter → 終了

    alfa_codo.append(i)  # 単語をリストに追加

    # 結果を表示
print(f"英単語を入力してください：{alfa_code}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       5 while True:
#       6     alfa_code= input("英単語を入力してください：")
# ----> 7     if  i == "":
#       8         break  # 未入力でEnter → 終了
#      10     alfa_codo.append(i)  # 単語をリストに追加
#
# NameError: name 'i' is not defined

# %%
# 空のリストを作成（英単語を格納）
words = []


# 未入力になるまで英単語を繰り返し受け付け
while True:
    words= input("英単語を入力してください：")
    if  i == "":
        break  # 未入力でEnter → 終了

    words.append(i)  # 単語をリストに追加


# 結果を表示
print(f"英単語を入力してください：{words}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       6 while True:
#       7     words= input("英単語を入力してください：")
# ----> 8     if  i == "":
#       9         break  # 未入力でEnter → 終了
#      11     words.append(i)  # 単語をリストに追加
#
# NameError: name 'i' is not defined

# %%
alfa_code = {}
alfa_code = dict.fromkeys(list("abcdefghijklmnopqrstuvwxyz"), 0)
alfa_code
# Out:
# {'a': 0,
#  'b': 0,
#  'c': 0,
#  'd': 0,
#  'e': 0,
#  'f': 0,
#  'g': 0,
#  'h': 0,
#  'i': 0,
#  'j': 0,
#  'k': 0,
#  'l': 0,
#  'm': 0,
#  'n': 0,
#  'o': 0,
#  'p': 0,
#  'q': 0,
#  'r': 0,
#  's': 0,
#  't': 0,
#  'u': 0,
#  'v': 0,
#  'w': 0,
#  'x': 0,
#  'y': 0,
#  'z': 0}

# %%
sample=["dog","cat","giraffe","kangaroo","horse","bear"]
alfa_code = dict.fromkeys(list("abcdefghijklmnopqrstuvwxyz"), 0) 
animals=[]
for i in sample:
    animals.append(i)
print(animals)
# Out:
# ['dog', 'cat', 'giraffe', 'kangaroo', 'horse', 'bear']

# %%
sample=["dog","cat","giraffe","kangaroo","horse","bear"]
alfa_code = dict.fromkeys(list("abcdefghijklmnopqrstuvwxyz"), 0) 
animals=[]
for i in sample:
    for j in i:
        print(j)
    animals.append(i)
# Out:
# d
# o
# g
# c
# a
# t
# g
# i
# r
# a
# f
# f
# e
# k
# a
# n
# g
# a
# r
# o
# o
# h
# o
# r
# s
# e
# b
# e
# a
# r

# %%
alfa_code = dict.fromkeys(list("abcdefghijklmnopqrstuvwxyz"), 0)
print(alfa_code)
alfa_code["a"]+=1
alfa_code["a"]+=1
print(alfa_code["a"])
# Out:
# {'a': 0, 'b': 0, 'c': 0, 'd': 0, 'e': 0, 'f': 0, 'g': 0, 'h': 0, 'i': 0, 'j': 0, 'k': 0, 'l': 0, 'm': 0, 'n': 0, 'o': 0, 'p': 0, 'q': 0, 'r': 0, 's': 0, 't': 0, 'u': 0, 'v': 0, 'w': 0, 'x': 0, 'y': 0, 'z': 0}
# 2

# %%
sample=["dog","cat","giraffe","kangaroo","horse","bear"]
alfa_code = dict.fromkeys(list("abcdefghijklmnopqrstuvwxyz"), 0)
animal=[]
for i in sample:
    for j in i:
        alfa_code[j]+=1
    animal.append(j)
print(alfa_code)
# Out:
# {'a': 5, 'b': 1, 'c': 1, 'd': 1, 'e': 3, 'f': 2, 'g': 3, 'h': 1, 'i': 1, 'j': 0, 'k': 1, 'l': 0, 'm': 0, 'n': 1, 'o': 4, 'p': 0, 'q': 0, 'r': 4, 's': 1, 't': 1, 'u': 0, 'v': 0, 'w': 0, 'x': 0, 'y': 0, 'z': 0}

# %%
sample=["dog","cat","giraffe","kangaroo","horse","bear"]
alfa_code = dict.fromkeys(list("abcdefghijklmnopqrstuvwxyz"), 0)
animal=[]
for i in sample:
    for j in i:
        alfa_code[j]+=1
    animal.append(j)
    # items

for key, value in alfa_code.items():
    print(f"{key} が {value}個ありました")
# Out:
# a が 5個ありました
# b が 1個ありました
# c が 1個ありました
# d が 1個ありました
# e が 3個ありました
# f が 2個ありました
# g が 3個ありました
# h が 1個ありました
# i が 1個ありました
# j が 0個ありました
# k が 1個ありました
# l が 0個ありました
# m が 0個ありました
# n が 1個ありました
# o が 4個ありました
# p が 0個ありました
# q が 0個ありました
# r が 4個ありました
# s が 1個ありました
# t が 1個ありました
# u が 0個ありました
# v が 0個ありました
# w が 0個ありました
# x が 0個ありました
# y が 0個ありました
# z が 0個ありました

# %%
sample=["dog","cat","giraffe","kangaroo","horse","bear"]
alfa_code = dict.fromkeys(list("abcdefghijklmnopqrstuvwxyz"), 0)
animal=[]
for i in sample:
    for j in i:
        alfa_code[j]+=1
    animal.append(j)
    # items

for key, value in alfa_code.items():
    if value >0:
        print(f"{key} が {value}個ありました")
# Out:
# a が 5個ありました
# b が 1個ありました
# c が 1個ありました
# d が 1個ありました
# e が 3個ありました
# f が 2個ありました
# g が 3個ありました
# h が 1個ありました
# i が 1個ありました
# k が 1個ありました
# n が 1個ありました
# o が 4個ありました
# r が 4個ありました
# s が 1個ありました
# t が 1個ありました

# %%
# 空のリストを作成（英単語を格納）
sample = []

# 未入力になるまで英単語を繰り返し受け付け
while True:
    i= input("英単語を入力してください：")
    if  i == "":
        break  # 未入力でEnter → 終了

    sample.append(i)  # 単語をリストに追加
# 結果を表示
print(f"英単語を入力してください：{sample}")
# Out:
# 英単語を入力してください：['dog']

# %%
# 空のリストを作成（英単語を格納）
sample = []

# 未入力になるまで英単語を繰り返し受け付け
while True:
    i= input("英単語を入力してください：")
    if  i == "":
        break  # 未入力でEnter → 終了

    sample.append(i)  # 単語をリストに追加
    print(f"英単語を入力してください：{i}")

# 結果を表示
print(f"入力した英単語：{sample}")
# Out:
# 英単語を入力してください：dog
# 英単語を入力してください：cat
# 英単語を入力してください：giraffe
# 英単語を入力してください：kangaroo
# 英単語を入力してください：horse
# 英単語を入力してください：bear
# 入力した英単語：['dog', 'cat', 'giraffe', 'kangaroo', 'horse', 'bear']
